# %%
text = "it"
text2 = "very "
print(text + '\'s ' + text2 + 'easy to write code!...', )
print(text,text2)
# Out:
# it's very easy to write code!...
# it very

# %%
print(input.__doc__)
# Out:
# Forward raw_input to frontends
#
#         Raises
#         ------
#         StdinNotImplentedError if active frontend doesn't support stdin.

# %%
isim = "OFaruk"
no = "C8281"
kurs = "clarusway"
print(isim, no, kurs)
# Out:
# OFaruk C8281 clarusway
